# %% [markdown]
# This below is the main code for preparing the data for analysis. I have 2 main data files: About 190-200 individul contract data for each month from 2009 to 2024 and a full continuous data set for the same time horizion. The granularity of this data is minute-level OHLCV.
